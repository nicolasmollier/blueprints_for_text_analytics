# %%
import pandas as pd
import os
import matplotlib
import seaborn as sns
import regex as re
import nltk
import numpy as np
import platform

# %% [markdown]
# ## 1. Data

# %%
data_path = "../blueprints-text/data"

# %%
df = pd.read_csv(os.path.join(data_path, "un-general-debates/un-general-debates-blueprint.csv"))

# %%
df.head()
# Out:
#    session  year country country_name             speaker position  \
# 0       25  1970     ALB      Albania             Mr. NAS      NaN
# 1       25  1970     ARG    Argentina  Mr. DE PABLO PARDO      NaN
# 2       25  1970     AUS    Australia         Mr. McMAHON      NaN
# 3       25  1970     AUT      Austria  Mr. KIRCHSCHLAEGER      NaN
# 4       25  1970     BEL      Belgium          Mr. HARMEL      NaN
#
#                                                 text
# 0  33: May I first convey to our President the co...
# 1  177.\t : It is a fortunate coincidence that pr...
# 2  100.\t  It is a pleasure for me to extend to y...
# 3  155.\t  May I begin by expressing to Ambassado...
# 4  176. No doubt each of us, before coming up to ...

# %% [markdown]
# ## 2. Summary Statistics for Columns

# %%
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %%
df.describe().T
# Out:
#           count         mean        std     min     25%     50%     75%  \
# session  7507.0    49.610763  12.892155    25.0    39.0    51.0    61.0
# year     7507.0  1994.610763  12.892155  1970.0  1984.0  1996.0  2006.0
#
#             max
# session    70.0
# year     2015.0

# %%
df['length'] = df.text.str.len()

# %%
df.describe().T
# Out:
#           count          mean          std     min      25%      50%      75%  \
# session  7507.0     49.610763    12.892155    25.0     39.0     51.0     61.0
# year     7507.0   1994.610763    12.892155  1970.0   1984.0   1996.0   2006.0
# length   7507.0  17967.281604  7860.038463  2362.0  12077.0  16424.0  22479.5
#
#              max
# session     70.0
# year      2015.0
# length   72041.0

# %%
df[['country', 'speaker']].describe(include='O').T
# Out:
#         count unique            top freq
# country  7507    199            ALB   46
# speaker  7480   5428  Seyoum Mesfin   12

# %%
df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %%
df['speaker'].fillna('unknown', inplace=True)

# %%
df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker            0
# position        3005
# text               0
# length             0
# dtype: int64

# %%
df[df.speaker.str.contains('Bush')].speaker.value_counts()
# Out:
# George W. Bush        4
# Mr. George W. Bush    2
# Bush                  1
# George Bush           1
# Mr. George W Bush     1
# Name: speaker, dtype: int64

# %% [markdown]
# ## 3. Plotting Value Distributions

# %%
matplotlib.style.use('ggplot')

# %%
df.length.plot(kind='box', vert=False, color='blue')
# Out:
# <AxesSubplot:>

# %%
df.length.plot(kind='hist', bins=30, color="blue")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
where = df.country.isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
sns.catplot(data=df[where], x='country', y='length', kind='box')

# %%
sns.catplot(data=df[where], x='country', y='length', kind='violin')

# %% [markdown]
# ## 4. Visualizing Developments over Time

# %%
df.groupby('year') \
    .size() \
    .plot(title='Number of Countries')
# Out:
# <AxesSubplot:title={'center':'Number of Countries'}, xlabel='year'>

# %%
df \
    .groupby('year') \
    .agg({'length': 'mean'}) \
    .plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ## 5. Building a simple Text preprocessing pipeline

# %% [markdown]
# ### 5.1 Tokenization with RegEx

# %%
def tokenize(text):
    return re.findall(r'[\w-]*\p{L}[\w-]*', text)

# %%
text = "Let's defeat SARS-CoV-2 together in 2020"
tokens = tokenize(text)
print("|".join(tokens))
# Out:
# Let|s|defeat|SARS-CoV-2|together|in

# %% [markdown]
# ### 5.2 Stop Words

# %%
stopwords = set(nltk.corpus.stopwords.words('english'))

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# %%
include_stopwords = {'dear', 'regards', 'must', 'would', 'also'}
exclude_stopwords = {'against'}

# %%
stopwords |= include_stopwords
stopwords -= exclude_stopwords

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'ain',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'dear',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'must',
#  'mustn',
# ...

# %%
len(stopwords)
# Out:
# 183

# %% [markdown]
# ### 5.3 Pipeline

# %%
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for transform in pipeline:
        tokens = transform(tokens)
    return tokens

# %%
df['tokens'] = df.text.apply(prepare, pipeline=pipeline)

# %%
df.head()
# Out:
#    session  year country country_name             speaker position  \
# 0       25  1970     ALB      Albania             Mr. NAS      NaN
# 1       25  1970     ARG    Argentina  Mr. DE PABLO PARDO      NaN
# 2       25  1970     AUS    Australia         Mr. McMAHON      NaN
# 3       25  1970     AUT      Austria  Mr. KIRCHSCHLAEGER      NaN
# 4       25  1970     BEL      Belgium          Mr. HARMEL      NaN
#
#                                                 text  length  \
# 0  33: May I first convey to our President the co...   51419
# 1  177.\t : It is a fortunate coincidence that pr...   29286
# 2  100.\t  It is a pleasure for me to extend to y...   31839
# 3  155.\t  May I begin by expressing to Ambassado...   26616
# 4  176. No doubt each of us, before coming up to ...   25911
#
#                                               tokens
# 0  [may, first, convey, president, congratulation...
# 1  [fortunate, coincidence, precisely, time, unit...
# ...

# %%
x = ['a', 'a', 'b']
np.unique(x)
# Out:
# array(['a', 'b'], dtype='<U1')

# %%
def unique_len(tokens):
    unique_tokens = np.unique(tokens)
    n_unique_tokens = len(unique_tokens)
    return(n_unique_tokens)

# %%
df['num_tokens'] = df.tokens.map(len)

# %%
df.tokens.map(unique_len)
# Out:
# 0       1459
# 1       1159
# 2       1319
# 3       1086
# 4       1013
#         ...
# 7502     526
# 7503    1175
# 7504     649
# 7505     687
# 7506     605
# Name: tokens, Length: 7507, dtype: int64

# %%
df.num_tokens
# Out:
# 0       4125
# 1       2327
# 2       2545
# 3       2135
# 4       2025
#         ...
# 7502     880
# 7503    2089
# 7504    1145
# 7505    1184
# 7506     896
# Name: num_tokens, Length: 7507, dtype: int64

# %% [markdown]
# ## 6 Word Frequency Analysis

# %% [markdown]
# ### 6.1 Counting Words

# %%
from collections import Counter

# %%
tokens = tokenize("She likes my cats and my cats like my sofa.")

# %%
tokens
# Out:
# ['She', 'likes', 'my', 'cats', 'and', 'my', 'cats', 'like', 'my', 'sofa']

# %%
counter = Counter(tokens)

# %%
counter
# Out:
# Counter({'She': 1,
#          'likes': 1,
#          'my': 3,
#          'cats': 2,
#          'and': 1,
#          'like': 1,
#          'sofa': 1})

# %%
more_tokens = tokenize("She likes dogs and cats.")
counter.update(more_tokens)

# %%
counter
# Out:
# Counter({'She': 2,
#          'likes': 2,
#          'my': 3,
#          'cats': 3,
#          'and': 2,
#          'like': 1,
#          'sofa': 1,
#          'dogs': 1})

# %%
counter = Counter()

# %%
counter
# Out:
# Counter()

# %%
# efficient
df.tokens.map(counter.update)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 7502    None
# 7503    None
# 7504    None
# 7505    None
# 7506    None
# Name: tokens, Length: 7507, dtype: object

# %%
counter
# Out:
# Counter({'may': 14987,
#          'first': 15965,
#          'convey': 1607,
#          'president': 18554,
#          'congratulations': 3714,
#          'albanian': 469,
#          'delegation': 13458,
#          'election': 7356,
#          'presidency': 3700,
#          'twenty-fifth': 555,
#          'session': 29391,
#          'general': 37138,
#          'assembly': 40413,
#          'taking': 5415,
#          'work': 20495,
#          'agenda': 8418,
#          'twenty-': 308,
#          'fifth': 974,
#          'held': 9531,
#          'eve': 380,
#          'anniversary': 3977,
#          'coming': 2045,
#          'force': 10190,
#          'charter': 16127,
#          'united': 120763,
#          'nations': 124508,
#          'peace-loving': 1062,
#          'member': 15440,
#          'states': 59713,
#          'wished': 285,
#          'position': 6450,
#          'present': 10769,
#          'occasion': 2464,
#          'picture': 742,
#          'positive': 7684,
# ...

# %%
counter.most_common(5)
# Out:
# [('nations', 124508),
#  ('united', 120763),
#  ('international', 117223),
#  ('world', 89421),
#  ('countries', 85734)]

# %%
def count_words(df, columns='tokens', preprocess=None, min_freq=2):
    # preprocess tokens and update counter
    def update(doc):
        tokens = doc if preprocess is None else preprocess(doc)
        counter.update(tokens)
    # create counter and run through all data
    counter = Counter()
    df[columns].map(update)
    # transform counter into DataFrame
    freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=["freq"])
    freq_df = freq_df.query('freq >= @min_freq')
    freq_df.index.name = 'token'
    
    return freq_df.sort_values('freq', ascending=False)

# %%
freq_df = count_words(df)

# %%
freq_df
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# ...               ...
# unrewarding         2
# israel-egypt        2
# non-jews            2
# shouf               2
# al-baydhah          2
#
# [40508 rows x 1 columns]

# %% [markdown]
# ### 6.2 Frequency Diagram

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95)
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ### 6.3 Word Clouds

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# %%
text = df.query("year==2015 and country=='USA'").text.values[0]
text
# Out:
# 'Seventy years after the founding of the United Nations it is worth reflecting on what the members of this body, working together, have helped to achieve. Out of the ashes of the Second World War, having witnessed the unthinkable power of the atomic age, the United States has worked with many nations in the Assembly to prevent a third world war — by forging alliances with old adversaries; by supporting the steady emergence of strong democracies accountable to their people and not to any foreign Power; and by building an international system that imposes a cost on those who choose conflict over cooperation, an order that recognizes the dignity and equal worth of all people.\nThat has been the work of seven decades. That is the ideal that this body has, at its best, pursued. Of course, there have been too many times when, collectively, we have fallen short of those ideals. Over the seven decades, terrible conflicts have claimed untold victims. But we have pressed forward, slowly, stead
# ...

# %%
wc = WordCloud(max_words=100, stopwords=stopwords)
wc

# %%
wc.generate(text)

# %%
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
counter = freq_df.freq
counter
# Out:
# token
# nations          124508
# united           120763
# international    117223
# world             89421
# countries         85734
#                   ...
# unrewarding           2
# israel-egypt          2
# non-jews              2
# shouf                 2
# al-baydhah            2
# Name: freq, Length: 40508, dtype: int64

# %%
wc = WordCloud(max_words=100, stopwords=stopwords)

# %%
counter.items()

# %%
counter = {token:freq for (token, freq) in counter.items()}
counter
# Out:
# {'nations': 124508,
#  'united': 120763,
#  'international': 117223,
#  'world': 89421,
#  'countries': 85734,
#  'peace': 72625,
#  'development': 62632,
#  'states': 59713,
#  'people': 59338,
#  'security': 58425,
#  'economic': 53833,
#  'new': 44453,
#  'country': 40878,
#  'assembly': 40413,
#  'community': 38294,
#  'government': 37430,
#  'general': 37138,
#  'organization': 36434,
#  'human': 36384,
#  'efforts': 35184,
#  'us': 34618,
#  'rights': 33495,
#  'political': 33353,
#  'one': 31840,
#  'africa': 31293,
#  'support': 30224,
#  'council': 29573,
#  'session': 29391,
#  'developing': 25977,
#  'peoples': 25161,
#  'time': 24870,
#  'against': 24089,
#  'order': 23581,
#  'republic': 23369,
#  'national': 23221,
#  'problems': 23176,
#  'many': 22849,
#  'year': 22702,
#  'situation': 22621,
#  'state': 22579,
#  'years': 22400,
#  'south': 22246,
#  'global': 21881,
#  'conference': 21719,
#  'region': 21470,
#  'social': 21133,
#  'like': 20566,
#  'work': 20495,
# ...

# %%
wc.generate_from_frequencies(counter)

# %%
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
freq_2015_df = count_words(df[df.year == 2015])

# %%
counter = freq_2015_df.freq
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate_from_frequencies(counter)
plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
counter = Counter()
def update_counter(doc):
    counter.update(doc)

# %%
df[df.year==2015].tokens.map(update_counter)
# Out:
# 7314    None
# 7315    None
# 7316    None
# 7317    None
# 7318    None
#         ...
# 7502    None
# 7503    None
# 7504    None
# 7505    None
# 7506    None
# Name: tokens, Length: 193, dtype: object

# %%
df_freq_2 = pd.DataFrame.from_dict(counter, orient='index', columns=['n'])
df_freq_2.index.name = "token"
df_freq_2.sort_values(ascending=False, inplace=True, by='n')
df_freq_2
# Out:
#                   n
# token
# nations        2587
# united         2571
# development    1754
# international  1727
# world          1635
# ...             ...
# ill-fated         1
# top-most          1
# sailing           1
# roundtable        1
# epochs            1
#
# [13682 rows x 1 columns]

# %%
df_freq_2.head(50).index
# Out:
# Index(['nations', 'united', 'development', 'international', 'world',
#        'security', 'peace', 'people', 'countries', 'states', 'human',
#        'country', 'us', 'global', 'rights', 'new', 'sustainable', 'years',
#        'one', 'climate', 'change', 'support', 'agenda', 'council', 'community',
#        'efforts', 'assembly', 'economic', 'today', 'organization',
#        'challenges', 'government', 'general', 'state', 'time', 'many', 'pv',
#        'like', 'work', 'political', 'year', 'cooperation', 'need', 'against',
#        'future', 'national', 'president', 'war', 'continue', 'goals'],
#       dtype='object', name='token')

# %%
counter = {token:freq for (token, freq) in counter.items() if token not in df_freq_2.head(50).index}

# %%
wc = WordCloud(max_words=100)
wc.generate_from_frequencies(counter)

# %%
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
freq_df.head(50)
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425
# economic        53833
# new             44453
# country         40878
# assembly        40413
# community       38294
# government      37430
# general         37138
# organization    36434
# human           36384
# efforts         35184
# us              34618
# rights          33495
# political       33353
# one             31840
# africa          31293
# support         30224
# council         29573
# session         29391
# developing      25977
# peoples         25161
# time            24870
# against         24089
# order           23581
# republic        23369
# national        23221
# problems        23176
# many            22849
# year            22702
# situation       22621
# state           22579
# ...

# %% [markdown]
# ## 7. TF-IDF

# %%
def compute_idf(df, column='tokens', preprocess=None, min_df=2):
    
    def update(doc):
        tokens = doc if preprocess is None else preprocess(doc)
        """
        'set' is important here: it is only checked whether a word is contained 
        in a given document not how many times (see TF-IDF definition and compare 
        with word count on page 16)
        """
        counter.update(set(tokens)) 
    
    # count tokens
    counter = Counter()
    df[column].map(update)
    # create DataFrame and compute idf
    idf_df = pd.DataFrame.from_dict(counter, orient='index', columns=['df'])
    idf_df = idf_df.query('df >= @min_df')
    idf_df['idf'] = np.log(len(df) / idf_df['df']) 
    idf_df.index.name="token"
    return(idf_df)

# %%
idf_df = compute_idf(df)
# Out:
# /tmp/ipykernel_11264/2784310115.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   idf_df['idf'] = np.log(len(df) / idf_df['df'])

# %%
idf_df
# Out:
#                    df       idf
# token
# accept           2072  1.287322
# guinea            542  2.628325
# trust            2141  1.254563
# plotting           23  5.788097
# year             6353  0.166909
# ...               ...       ...
# tatars              3  7.824979
# decarbonization     2  8.230444
# fit-for-purpose     2  8.230444
# shamin              2  8.230444
# baal                2  8.230444
#
# [39373 rows x 2 columns]

# %%
freq_df['tfidf'] = freq_df['freq'] * idf_df['idf']

# %%
freq_df
# Out:
#                  freq        tfidf
# token
# nations        124508   199.186284
# united         120763   209.308632
# international  117223   641.976226
# world           89421   561.608982
# countries       85734  2315.085986
# ...               ...          ...
# unrewarding         2    16.460888
# israel-egypt        2    16.460888
# non-jews            2    16.460888
# shouf               2    16.460888
# al-baydhah          2          NaN
#
# [40508 rows x 2 columns]

# %%
freq_1970 = count_words(df.query('year == 1970'))
freq_2015 = count_words(df.query('year == 2015'))

# %%
freq_1970['tfidf'] = freq_1970.freq * idf_df.idf
freq_2015['tfidf'] = freq_2015.freq * idf_df.idf

# %%
freq_1970
# Out:
#                freq      tfidf
# token
# nations        1997   3.194775
# united         1996   3.459504
# international  1251   6.851149
# world          1093   6.864591
# peace           970  24.468823
# ...             ...        ...
# frangois          2        NaN
# emphatic          2  10.371843
# agonizing         2   9.033744
# clocks            2  15.649958
# sanity            2   9.761080
#
# [7161 rows x 2 columns]

# %%
freq_1970
# Out:
#                freq      tfidf
# token
# nations        1997   3.194775
# united         1996   3.459504
# international  1251   6.851149
# world          1093   6.864591
# peace           970  24.468823
# ...             ...        ...
# frangois          2        NaN
# emphatic          2  10.371843
# agonizing         2   9.033744
# clocks            2  15.649958
# sanity            2   9.761080
#
# [7161 rows x 2 columns]

# %%
freq_1970_without_stopwords = {
    token:freq for (token, freq) in freq_1970.freq.to_dict().items() if token not in ['twenty-five', 'twenty-fifth']
}
freq_2015_without_stopwords = {
    token:freq for (token, freq) in freq_2015.freq.to_dict().items() if token not in ['seventieth']
}

tfidf_1970_without_stopwords = {
    token:tfidf for (token, tfidf) in freq_1970.tfidf.to_dict().items() if token not in ['twenty-five', 'twenty-fifth']
}
tfidf_2015_without_stopwords = {
    token:tfidf for (token, tfidf) in freq_2015.tfidf.to_dict().items() if token not in ['seventieth']
}

# %%
figure, axis = plt.subplots(2, 2, figsize=(15, 8))
wc = WordCloud(max_words=200, colormap="Paired")
wc.generate_from_frequencies(freq_1970_without_stopwords)
axis[0,0].imshow(wc)
axis[0,0].axis('off')

wc = WordCloud(max_words=200, colormap="Paired")
wc.generate_from_frequencies(freq_2015_without_stopwords)
axis[0,1].imshow(wc)
axis[0,1].axis('off')

wc = WordCloud(max_words=200, colormap="Paired")
wc.generate_from_frequencies(tfidf_1970_without_stopwords)
axis[1,0].imshow(wc)
axis[1,0].axis('off')

wc = WordCloud(max_words=200, colormap="Paired")
wc.generate_from_frequencies(tfidf_2015_without_stopwords)
axis[1,1].imshow(wc)
axis[1,1].axis('off')

axis[0,0].set_title('1970 - TF')
axis[0,1].set_title('2015 - TF')
axis[1,0].set_title('1970 - TF-IDF')
axis[1,1].set_title('2015 - TF-IDF')
# Out:
# Text(0.5, 1.0, '2015 - TF-IDF')

# %%
freq_1970.freq.to_dict()
# Out:
# {'nations': 1997,
#  'united': 1996,
#  'international': 1251,
#  'world': 1093,
#  'peace': 970,
#  'countries': 908,
#  'states': 896,
#  'organization': 762,
#  'people': 649,
#  'development': 643,
#  'security': 594,
#  'peoples': 567,
#  'assembly': 552,
#  'charter': 551,
#  'government': 541,
#  'one': 527,
#  'general': 525,
#  'economic': 448,
#  'us': 401,
#  'years': 392,
#  'great': 369,
#  'time': 365,
#  'war': 360,
#  'new': 353,
#  'country': 348,
#  'rights': 335,
#  'problems': 331,
#  'africa': 331,
#  'against': 329,
#  'human': 321,
#  'may': 317,
#  'republic': 316,
#  'principles': 312,
#  'political': 307,
#  'session': 304,
#  'developing': 299,
#  'first': 296,
#  'progress': 293,
#  'arab': 293,
#  'many': 290,
#  'national': 280,
#  'powers': 278,
#  'hope': 269,
#  'council': 268,
#  'delegation': 265,
#  'president': 264,
#  'made': 260,
#  'problem': 254,
#  'social': 253,
#  'two': 248,
#  'among': 246,
#  'efforts': 244,
#  'law': 243,
# ...

# %% [markdown]
# ## 8. Finding a keyword-in-context

# %%
from textacy.extract.kwic import keyword_in_context

# %%
list(keyword_in_context(df.text[0], "Leninist"))
# Out:
# [('y the unflinching struggle which was waged by the ',
#   'Leninist',
#   ' Soviet Union in the world arena, as well as by it'),
#  ('ion of the General Assembly, guided by the Marxist',
#   'Leninist',
#   ' principles of our Socialist State, will continue,')]

# %%
def kwic_for_multiple_docs(doc_series, keyword, window=35):
    def add_kwic(text):
        kwic_list.extend(keyword_in_context(text, keyword, ignore_case=True, window_width=window))
    kwic_list = []
    doc_series.map(add_kwic)
    return(kwic_list)

# %%
kwic_for_multiple_docs(df.text, "sdgs")
# Out:
# [('of sustainable development \ngoals (',
#   'SDGs',
#   '). My delegation believes that in o'),
#  ('\nthe processes of the MDGs and the ',
#   'SDGs',
#   '. The \nCommonwealth of Dominica the'),
#  ('ation should form \nthe core of the ',
#   'SDGs',
#   ' and the post-2015 development \nage'),
#  ('of sustainable \ndevelopment goals (',
#   'SDGs',
#   '), which would build upon the \nMDGs'),
#  (' is our hope that we \nwill develop ',
#   'SDGs',
#   ' that are simple to implement, whil'),
#  ('nd sustainable \ndevelopment goals (',
#   'SDGs',
#   ') are not seen in isolation from \nt'),
#  (' the MDGs. The \nformulation of the ',
#   'SDGs',
#   ' and the post-2015 development \nage'),
#  ('he sustainable development goals \n(',
#   'SDGs',
#   ') should be universal and applicabl'),
#  ('lar the Open Working \nGroup on the ',
#   'SDGs',
#   '.\n\nWe strongly believe that the tim'),
#  ('the sustainable development goals (',
#   'SDGs',
# ...

# %% [markdown]
# ## 9. Analyzing N-Grams

# %%
def ngrams(tokens, n=2, sep=' '):
    return([sep.join(ngram) for ngram in zip(*[tokens[i:] for i in range(n)])])

# %%
text = "the visisble manifestation of the global climate change"

# %%
tokens = tokenize(text)

# %%
tokens
# Out:
# ['the',
#  'visisble',
#  'manifestation',
#  'of',
#  'the',
#  'global',
#  'climate',
#  'change']

# %%
print("|".join(ngrams(tokens, 2)))
# Out:
# the visisble|visisble manifestation|manifestation of|of the|the global|global climate|climate change

# %%
ngrams(tokens, 2)
# Out:
# ['the visisble',
#  'visisble manifestation',
#  'manifestation of',
#  'of the',
#  'the global',
#  'global climate',
#  'climate change']

# %%
def ngrams(tokens, n=2, sep=' ', stopwords=set()):
    return([sep.join(ngram) for ngram in zip(*[tokens[i:] for i in range(n)]) if len([t for t in ngram if t in stopwords]) ==0])

# %%
ngrams(tokens, 2, stopwords=stopwords)
# Out:
# ['visisble manifestation', 'global climate', 'climate change']

# %%
ngrams(tokens, 3, stopwords=stopwords)
# Out:
# ['global climate change']

# %%
df['bigrams'] = df.text.apply(prepare, pipeline=[str.lower, tokenize]).apply(ngrams, n=2, stopwords=stopwords)

# %%
count_words(df, "bigrams").head(n=5)
# Out:
#                            freq
# token
# united nations           103236
# international community   27786
# general assembly          27096
# security council          20961
# human rights              19856

# %%
idf_df
# Out:
#                    df       idf
# token
# accept           2072  1.287322
# guinea            542  2.628325
# trust            2141  1.254563
# plotting           23  5.788097
# year             6353  0.166909
# ...               ...       ...
# tatars              3  7.824979
# decarbonization     2  8.230444
# fit-for-purpose     2  8.230444
# shamin              2  8.230444
# baal                2  8.230444
#
# [39373 rows x 2 columns]

# %%
idf_df2 = compute_idf(df, "bigrams", min_df=10)
# Out:
# /tmp/ipykernel_11264/2784310115.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   idf_df['idf'] = np.log(len(df) / idf_df['df'])

# %%
idf_df2
# Out:
#                           df       idf
# token
# people against           108  4.241460
# conventional armaments   112  4.205092
# peoples against           77  4.579786
# european states          206  3.595715
# foreign policy          1407  1.674376
# ...                      ...       ...
# intended nationally       15  6.215541
# paris later               10  6.621006
# ababa action              26  5.665495
# independent panel         16  6.151002
# high-level independent    15  6.215541
#
# [45828 rows x 2 columns]

# %%
freq_df = count_words(df[df.year == 2015], 'bigrams')
freq_df
# Out:
#                          freq
# token
# united nations           2255
# sustainable development   580
# human rights              574
# climate change            532
# international community   459
# ...                       ...
# landmark achievement        2
# changing realities          2
# necessary financial         2
# somalia amisom              2
# without distinction         2
#
# [7893 rows x 1 columns]

# %%
freq_df["tfidf"] = freq_df["freq"] * idf_df2["idf"]

# %%
idf_df2[idf_df2.index == "united nations"]
# Out:
#                   df       idf
# token
# united nations  7472  0.004673

# %%
freq_df[freq_df.index == "united nations"]
# Out:
#                 freq      tfidf
# token
# united nations  2255  10.538106

# %%
0.004673*2255
# Out:
# 10.537615

# %%
wc = WordCloud()

# %%
wc.generate_from_frequencies(freq_df.tfidf)

# %%
plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
filter_idx = freq_df.index.str.contains("climate")
wc = WordCloud()
wc.generate_from_frequencies(freq_df.loc[filter_idx,"freq"])

# %%
plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ## 10. Comparing Frequencies across Time Intervals and Categories

# %% [markdown]
# ### Create Frequency Timelines

# %%
def count_keywords(tokens, keywords):
    tokens = [t for t in tokens if t in keywords]
    counter = Counter(tokens)
    #print(counter)
    return([counter.get(k, 0) for k in keywords])

# %%
keywords = ['nuclear', 'terrorism', 'climate', 'freedom']
tokens = ['nuclear', 'climate', 'climate', 'freedom', 'climate', 'freedom']

# %%
count_keywords(tokens, keywords)
# Out:
# [1, 0, 3, 2]

# %%
def count_keywords_by(df, by, keywords, column='tokens'):
    freq_matrix = df[column].apply(count_keywords, keywords=keywords)
    freq_df = pd.DataFrame.from_records(freq_matrix, columns=keywords)
    freq_df[by] = df[by]
    return freq_df.groupby(by=by).sum().sort_values(by)

# %%
freq_df = count_keywords_by(df=df, by="year", keywords=keywords)

# %%
freq_df.head()
# Out:
#       nuclear  terrorism  climate  freedom
# year
# 1970      192          7       18      128
# 1971      275          9       35      205
# 1972      393        379       74      280
# 1973      347        124       79      266
# 1974      478         24       71      316

# %%
freq_df.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ## 11. Frequency Heatmap

# %%
keywords = ["terrorism", "terrorist", "nuclear", "war", "oil", "syria", "syrian", "refugees", "migration", "peacekeeping", "humanitarian", "climate", "change", "sustainable", "sdgs"]

# %%
freq_df = count_keywords_by(df, by="year", keywords=keywords)

# %%
freq_df.head()
# Out:
#       terrorism  terrorist  nuclear  war  oil  syria  syrian  refugees  \
# year
# 1970          7          9      192  360    1      7      15        16
# 1971          9          8      275  468   10     16      21       161
# 1972        379         75      393  562   12     38      32        41
# 1973        124         19      347  612   24     45      14        29
# 1974         24         13      478  466  247     28      10        55
#
#       migration  peacekeeping  humanitarian  climate  change  sustainable  \
# year
# 1970          1            45            28       18      57            0
# 1971          1            17            64       35      94            0
# 1972          1             5            42       74     124            0
# 1973          0             5            51       79     157            0
# 1974          2            23            46       71     187            0
#
#       sdgs
# year
# 1970     0
# 1971     0
# 1972     0
# 1973     0
# ...

# %%
n_tokens_per_year = df.groupby("year").num_tokens.sum()
n_tokens_per_year.head()
# Out:
# year
# 1970    136630
# 1971    226734
# 1972    242449
# 1973    240260
# 1974    255596
# Name: num_tokens, dtype: int64

# %%
freq_df = freq_df.div(n_tokens_per_year, axis=0)
freq_df.head()
# Out:
#       terrorism  terrorist   nuclear       war       oil     syria    syrian  \
# year
# 1970   0.000051   0.000066  0.001405  0.002635  0.000007  0.000051  0.000110
# 1971   0.000040   0.000035  0.001213  0.002064  0.000044  0.000071  0.000093
# 1972   0.001563   0.000309  0.001621  0.002318  0.000049  0.000157  0.000132
# 1973   0.000516   0.000079  0.001444  0.002547  0.000100  0.000187  0.000058
# 1974   0.000094   0.000051  0.001870  0.001823  0.000966  0.000110  0.000039
#
#       refugees  migration  peacekeeping  humanitarian   climate    change  \
# year
# 1970  0.000117   0.000007      0.000329      0.000205  0.000132  0.000417
# 1971  0.000710   0.000004      0.000075      0.000282  0.000154  0.000415
# 1972  0.000169   0.000004      0.000021      0.000173  0.000305  0.000511
# 1973  0.000121   0.000000      0.000021      0.000212  0.000329  0.000653
# 1974  0.000215   0.000008      0.000090      0.000180  0.000278  0.000732
#
#       sustainable  sdgs
# year
# ...

# %%
freq_df = freq_df.apply(np.sqrt)

# %%
freq_df.head()
# Out:
#       terrorism  terrorist   nuclear       war       oil     syria    syrian  \
# year
# 1970   0.007158   0.008116  0.037487  0.051331  0.002705  0.007158  0.010478
# 1971   0.006300   0.005940  0.034826  0.045432  0.006641  0.008400  0.009624
# 1972   0.039538   0.017588  0.040261  0.048146  0.007035  0.012519  0.011489
# 1973   0.022718   0.008893  0.038004  0.050470  0.009995  0.013686  0.007633
# 1974   0.009690   0.007132  0.043245  0.042699  0.031086  0.010467  0.006255
#
#       refugees  migration  peacekeeping  humanitarian   climate    change  \
# year
# 1970  0.010821   0.002705      0.018148      0.014315  0.011478  0.020425
# 1971  0.026647   0.002100      0.008659      0.016801  0.012424  0.020361
# 1972  0.013004   0.002031      0.004541      0.013162  0.017471  0.022615
# 1973  0.010986   0.000000      0.004562      0.014569  0.018133  0.025563
# 1974  0.014669   0.002797      0.009486      0.013415  0.016667  0.027049
#
#       sustainable  sdgs
# year
# ...

# %%
sns.heatmap(data=freq_df.T, cmap="Reds", cbar=False)
# Out:
# <AxesSubplot:xlabel='year'>
